# %%
import hashlib
from bs4 import BeautifulSoup
import json
import re

# Function to generate a unique ID
def generate_id(name, date):
    unique_string = f"{name}_{date}"
    return hashlib.md5(unique_string.encode()).hexdigest()

# Function to split and prepend the prefix to each number
def split_and_prepend(input_string):
    # Find the position of the first comma
    first_comma_index = input_string.index(',')
    
    # Extract the prefix
    prefix = input_string[:first_comma_index].rsplit(' ', 1)[0]
    
    # Extract the numbers part
    numbers_part = input_string[first_comma_index + 1:]
    
    # Split the numbers part by comma and strip whitespace
    numbers = [num.strip() for num in numbers_part.split(",")]
    
    # Prepend the prefix to each number
    result = [f"{prefix} {num}" for num in numbers]
    
    return result

# Load the HTML content
# Specify the path to your HTML file
file_path = "mvp.html"  # Replace with the actual path to your HTML file

# Load the HTML content from the file
with open(file_path, "r", encoding="utf-8") as file:
    html_content = file.read()
    soup = BeautifulSoup(html_content, "html.parser")

    # Initialize an empty list for structured data
    entries = []

    # Iterate through each <thead> (entry header)
    for entry in soup.find_all("thead"):
        # Extract the name and date
        name_date = entry.find_all("th")
        if len(name_date) == 2:
            name = name_date[0].get_text(strip=True)
            date = name_date[1].get_text(strip=True)

            # Generate a unique ID for the entry
            unique_id = generate_id(name, date)

            # Initialize the entry dictionary
            entry_data = {
                "ID": unique_id,
                "Name": name,
                "Date": date,
                "Sources": [],
                "Facts": []
            }

            # Find the corresponding <blockquote> for this entry
            blockquote = entry.find_next("blockquote")
            if blockquote:
                # Extract sources and their references
                sources_text = blockquote.find("p").decode_contents().replace("\n", "")
                sources = []
                source_map = {}  # Map letters (e.g., 'a', 'b') to references
                for source in sources_text.split(";"):
                    parts = source.split(",")
                    if len(parts) > 1:
                        # Use split_and_prepend to handle the prefix
                        prefixed_parts = split_and_prepend(source)
                        for part in prefixed_parts:
                            match = re.match(r"^(.*?)<sup>([a-z]+)</sup>$", part.strip())
                            if match:
                                resource = match.group(1).strip()
                                references = list(match.group(2))  # Extract individual letters
                                for ref in references:
                                    sources.append({"Resource": resource, "Reference": ref})
                                    source_map[ref] = resource  # Map each letter to its resource
                    else:
                        match = re.match(r"^(.*?)<sup>([a-z]+)</sup>$", source.strip())
                        if match:
                            resource = match.group(1).strip()
                            references = list(match.group(2))  # Extract individual letters
                            for ref in references:
                                sources.append({"Resource": resource, "Reference": ref})
                                source_map[ref] = resource  # Map each letter to its resource
                        else:
                            resource = source.strip()
                            sources.append({"Resource": resource})

                entry_data["Sources"] = sources

                # Extract facts and their references
                for fact_line in blockquote.find_all("p")[1:]:  # Skip the first <p> (sources)
                    fact_text = fact_line.decode_contents().replace("\n", "")
                    # Split the fact text by commas and process each part
                    for part in fact_text.split(","):
                        match = re.match(r"^(.*?)<sup>([a-z]+)</sup>$", part.strip())
                        if match:
                            fact = match.group(1).strip()
                            references = list(match.group(2))  # Extract letters
                            entry_data["Facts"].append({
                                "Fact": fact,
                                "Sources": references
                            })
                        else:
                            # Handle lines without <sup> tags
                            fact = part.strip()
                            entry_data["Facts"].append({
                                "Fact": fact,
                                "Sources": []
                            })

            # Append the entry to the entries list
            entries.append(entry_data)

    # Output the structured data as JSON
    output_file = "output_with_ids7.json"  # Specify your output file name
    with open(output_file, "w", encoding="utf-8") as f:
        json.dump(entries, f, ensure_ascii=False, indent=4)

    print(f"Data extraction complete. Saved to '{output_file}'.")
# Out:
# Grunauer, p. 53 (emission mark 6 <img alt="sigla 06" src="media/image1.jpeg" style="width:0.27083in
# height:0.11806in"/>), Gruppe XIII(48-40 BC), Serie 5, Tafel 8, Gruppe XIV (48-40 BC), Serie 11, Tafel 8,Gruppe XV (48-40 BC), Serie 9-10, Tafel 9, Gruppe XVI (43-31 BC), Serie1, Tafel 11 suggests Amphimachos or Amphis (but the abbreviation seemsto include a rho)
# Rizakis #247
#  IG V 1. 682
# Rizakis #247
#  IG V 1. 682
# SEG XI 565
# IG V 1. 118 (partial A)
# IG V 1. 94 (partial A, 3-4 letters missing)
# Rizakis #379
#  IG V 1. 786 (partial A)
# Rizakis #248 (“Severan”)
#  IG V 1. 303
# Rizakis #248 (“Severan”)
#  IG V 1. 303
# Rizakis #248 (“Severan”)
#  IG V 1. 303
# IG V 1. 380
# IG VII 417<sup>a</sup>
#  [XII. 3 (supplement) 1299<sup>b</sup>,1625<sup>c</sup>]
# IG VII 417<sup>a</sup>
#  [XII. 3 (supplement) 1299<sup>b</sup>,1625<sup>c</sup>]
# IG VII 417<sup>a</sup>
#  [XII. 3 (supplement) 1299<sup>b</sup>,1625<sup>c</sup>]
# IG V 1. 212
# [IG VII 417]<sup>a</sup>
#  XII. 3 (supplement) 1299<sup>b</sup>,1625<sup>c</sup>
# Grunauer, p. 53 (emission mark 2 <img alt="sigla 02" src="media/image2.jpeg" style="width:0.13889in
# height:0.13194in"/>), Gruppe XIII(48-40 BC), Serie 2-3, Tafel 8, XIV (48-40 BC), 2-5, T 8, Gruppe XV(48-40 BC), Serie 2, Tafel 9 suggests Agathokles (but there seems to bea symbol for rho)
# IG V 1. 179
# IG V 1. 198 (or Ap—)
# IG V 1. 676
# IG V 1. 177
# Rizakis #198 (“Antoninus Pius”)
#  IG V 1. 472<sup>a</sup>,663<sup>b</sup>
# Father of Anonymus (Fragment 2)
# Lover of Phalanthos, the mythical founder of Tarentum, whose life heis supposed to have saved
# Son of Sosinik[os] (6)
# Rizakis 597
#  IG V 1. 115 (SEG XI 592)
# Rizakis 736
#  IG V 1. 66, 67
# Rizakis #81 {has [Α]ὐρ(ήλιος)}
#  IG V 1. 682
# Galen (ed. C. G. Kühn, Leipzig, 1821-33) <em>de febriumdifferentiis</em> II 9 (VII 367), <em>de pulsum differentia</em> IV10-11 (VIII 748-54), <em>de dignoscendis pulsibus</em> I 3 (VIII 787),IV 2 (VIII 935-37), <em>de venae sectione adversus Erasistratum</em> 5(XI 163), <em>de compositione medicamentorum per genera</em> V 11 (XIII830), <em>Hippocratis Epidemion I et Galeni in illum commentarius</em>II 25 (XVII 1, 120), <em>Hippocratis Epidemion VI et Galeni in illumcommentarius</em> II 26 (XVII 1, 942-43), <em>definitiones medicae</em>14 (XIX 353)
#  <em>vita A. Persi Flacci</em>
#  <em>Hellenica</em> <em>Oxyrhyncus</em>11.2-5, 12.1-4, 13.1, 21.1-4, 22.2,4<sup>w</sup>
#  Xenophon<em>Agesilaus</em> (1.25-35<sup>x</sup>
#  2.17<sup>y</sup>,21<sup>z</sup>, 26-7<sup>A</sup>, 9.6<sup>B</sup>)
# <em>Hellenica</em><sup>C</sup> III 3-4 passim
#  IV-VI passim, VII 5.9,10
#  Aristotle <em>Politica</em> 1306b35
#  SEG XI 457 (father?)
#  Libanius<em>declamationes</em> XXIV 2 (<em>mel</em>): 6
#  Isocrates<em>epistulae</em> IX 11-14, <em>orationes</em> IV 144, 153, V 62, 86,87
#  Athenaeus IV 144<span class="smallcaps">b</span>, IX 384<span class="smallcaps">a</span>, XII 511<span class="smallcaps">c</span>,550<span class="smallcaps">e</span>, XIII 609<span class="smallcaps">b</span>, XIV 613<span class="smallcaps">c</span>,616<span class="smallcaps">d</span>, 657<span class="smallcaps">b</span>
#  Josephus <em>Bellum Judaicum</em> II 359
# Diogenes Laertius II 51, 52, 57, VI 39, VIII 87
#  <em>Die In­schrif­ten vonEphesos</em> (der Österreichischen Akademie der Wissen­schaften) II133
# Poralla 10 (cf. Appendix Eurypontiden)
#  Herodotus VI 65 (“Agis”),
# Poralla 11 (cf. Appendix Eurypontiden)
#  Arrian <em>Anabasis</em>2.13.6
#  Plutarch
# Poralla 12
#  IG V 1. 3
# Poralla 12a
#  [Plutarch] <em>Moralia</em> (<em>Parallela minora</em>10) 308<span class="smallcaps">b</span>
# IG V 1. 79
# Plutarch <em>Agis</em> 6.3-7.2<sup>a</sup>, 9.1<sup>b</sup>,12.4-13.5<sup>c</sup>, 16.1-5<sup>d</sup>, 18.5<sup>e</sup>,19.6<sup>f</sup>
#  <em>comparatio Agis Cleomenes Ti. Gracchus C.Gracchus</em> 4.1<sup>g</sup>
#  Polybius IV 35.13<sup>h</sup>
#  IG XII 8.156<sup>i</sup>
#  <em>Prometheus</em> VII 1981, pp. 35-42: Agis becameking as a child and Agesilaos was his regent.
# IG V 1. 278
# Rizakis #416
#  IG V 1. [18A]<sup>a</sup>, 19<sup>b</sup>, 191 (cf. SEGXI 567)<sup>c</sup>, 378<sup>d</sup>, 667<sup>e</sup>
#  SEG XI 559 (andIG V 1. 58: ἐπὶ —λάου?)<sup>f</sup>
# Rizakis #358 (two individuals)
#  IG V 1. 378 (error of inscriber forCharixenos [6]?—a conflation of Flavius Charixenos and JuliusAgesilaos?)
# Rizakis #358 (two individuals)
#  IG V 1. 378 (error of inscriber forCharixenos [6]?—a conflation of Flavius Charixenos and JuliusAgesilaos?)
# IG V 1. 79
# IG V 1. 95
# IG V 1. 210
# SEG XI 558
# IG V 1. 95<sup>a</sup>, 135<sup>b</sup>
# IG V 1. 50<span class="smallcaps">b</span>
#  SEG XI 505
# SEG XI 569
# Poralla 14
#  Diodorus XIV 89<sup>a</sup>, XV 22,2, 23,2<sup>b</sup>
#  SEG XI539<sup>d</sup>, 564<sup>e</sup>, 569<sup>f</sup>, 641<sup>g</sup>
# IG V 1. 124
# IG V 1. 49 (restored because of the name Damokratidas)
# IG V 1. 60 (restored from AIΓIAΛOΥ in an inscription &lt
# ortranscription&gt
#
# IG V 1. 64
# Poralla 21
#  Herodotus IX 33 (the name is known in the Ionianform:
# Son of Agelochos
# Poralla 23
#  <em>FDelph</em> III<sub>5</sub>. 19, 65
# IG V 1. 210
# Plutarch <em>Cleomenes</em> 1.1-3, 22.1-3, [<em>Aratus</em> 39.3]
# Poralla 24
#  D. L. Page, <em>Alcman, the Partheneion</em>, Oxford.1951)
# Rizakis #60
#  IG V 1. 653b
# IG V 1. 714
# SEG XI 543
# SEG XI 543
# IG V 1. 114<sup>a</sup>
#  SEG XI 516<sup>b</sup>
# IG V 1. 1295
# Poralla 25
#  Herodotus I 65<sup>a</sup>, VII 204<sup>b</sup>
#  StraboVIII 365<sup>c</sup>
#  Pausanias III 16.9<sup>d</sup>
# Poralla 26
#  Thucydides III 89<sup>a</sup>, IV 2. 6<sup>b</sup>, V 19,24<sup>c</sup>, 54<sup>d</sup>, 57-60 &amp
#  63-75<sup>e</sup>,83<sup>f</sup>, VII 19 &amp
#  27<sup>g</sup>, VIII 3<sup>h</sup>, 5-11&amp
#  70-71<sup>i</sup>
#  Plutarch <em>Agesilaus</em> 1. 3<sup>j</sup>
# Diodorus XI 48<sup>k</sup>, XII 35.4<sup>l</sup>, 78-79<sup>m</sup>,XIII 107<sup>n</sup>
#  Xenophon <em>Hellenica</em> I 1.33-35<sup>o</sup>,II 2. 7-13<sup>p</sup>, II 3.3<sup>q</sup>, III 2.22-29 &amp
# 3.1<sup>r</sup>
#  Pausanias III 8.3-5<sup>s</sup>, VI 2.3<sup>t</sup>
# <em>IDelos</em> 87 (IG V 1. 1564)
#  Justin V 2.5
#  Nepos<em>Agesilaus</em> 1
#  Athenaeus XII 535<span class="smallcaps">b</span>,543<span class="smallcaps">b</span>
# Poralla 27
#  Plutarch <em>Agis</em> 3<sup>a</sup>
#  Pausanias III10.5<sup>b</sup>
#  Arrian <em>Anabasis</em> II 13.6<sup>c</sup>
#  DiodorusXVI 88.4<sup>d</sup>, XVII 48.1-2<sup>e</sup>, 62.6-63.4<sup>f</sup>
# Curtius VI 1<sup>g</sup>
# Poralla 28
#  Nikandros <em>Anthologia Palatina</em> VII 435
# SEG I 87 (dated by letter forms)
# SEG I 87 (dated by letter forms)
# SEG I 87 (dated by letter forms)
# Plutarch <em>Agis</em> passim, <em>Cleomenes</em> 1-3,<em>Agesilaus</em> 40.5
#  <em>comparatio Agis Cleo­menes Ti. Gracchus C.Gracchus</em>, <em>Aratus</em> 31.1
#  <em>Moralia</em> (<em>apophthegmataLaconica</em>) 216<span class="smallcaps">d</span>
#  <em>Lampriascatalogue</em> Number 9
#  Cicero <em>de officiis</em> II 80
#  Pausanias II8.5
#  III 10.5
#  VI 2.4
#  VII 7.3
#  VIII 8.11, 10.5-8, 27.13-14, 36.6(Pausanias confuses Agis IV and Archidamos IV)
#  <em>Prometheus</em> VII1981, pp. 35-42: Agis became king as a child with Agesilaos as hisregent.
# Rizakis 640 (Stemmata 1, 11)
#  IG V 1. 71 (ΠΟ)<sup>a</sup>, 86 (ΓΑΠΩΝΠΟΝΙΟΣ)<sup>b</sup>, 494 (ΓΑ ΠΟΜΠΩ)<sup>c</sup>
# SEG XI 856
# IG V 1. 43<sup>a</sup>, 281<sup>b</sup>, 358<sup>c</sup>
# IG V 1. 211
# SEG XI 532
# SEG I 87
# IG V 1. 210
# IG V 1. 588
# IG V 1. 210<sup>a</sup>, 212<sup>b</sup>
# [IG V 1. 102 (cf. SEG XI 579)<sup>a</sup>
#  121 (ΑΠ—, the Π is ΓΙ inligature, cf. SEG XI 574)<sup>b</sup>]
#  SEG XI 490<sup>c</sup>,544<sup>d</sup>
# Rizakis #418
#  SEG XI 503
# IG V 1. 177 (cf. SEG XI 634)
# SEG XI 585
#  Steinhauer, BSA 93, pp. 427-447, #2, plate 71b
# IG V 1. 195
# SEG XI 546
# Mother of Faustus, two more sons, and a daughter
# Grunauer, Gruppe VIII, Serie 18 (<img alt="Esigla 18" src="media/image5.jpeg" style="width:0.36806in
# height:0.10417in"/>), Tafel 5(102)
# Ephor who survived an attack of the supporters of Kleomenes (1) IIIby simulating death and taking sanctuary in the temple of Phobos
# Ephor who survived an attack of the supporters of Kleomenes (1) IIIby simulating death and taking sanctuary in the temple of Phobos
# Poralla 29
#  IG V 1. 1134
# Poralla 30
#  Herodotus V 63 (Ἀγχιμόλιος)
#  Aristotle <em>AthenaionPoliteia</em> 19, Scholia to Aristophanes <em>Lysistrata</em> 1153
# Poralla 30
#  Herodotus V 63 (Ἀγχιμόλιος)
#  Aristotle <em>AthenaionPoliteia</em> 19, Scholia to Aristophanes <em>Lysistrata</em> 1153
# Polybius IV 22.7-23.9
#  J. Toepffer, “Adeimantos (7),” RE, I Halbband(Stuttgart, 1893), 355
# Polybius IV 22.7-23.9
#  J. Toepffer, “Adeimantos (7),” RE, I Halbband(Stuttgart, 1893), 355
# SEG XI 626
# SEG XI 626
# Poralla 31
#  Plutarch <em>Aristides</em> 19 (Ἀρίμνηστος)
#  Herodotus IX64, Aristodemus II 5 in Müller, <em>Fragmenta HistoricorumGraecorum</em>, Paris, 1878, V 5
#  Pausanias I 27.1 (not named, cf.Poralla 790)
# Poralla 32
#  Thucydides IV 119, 122
# Son (?) of Makedo[n] (1)
# Son (?) of Makedo[n] (1)
# IG V 1. 133
# IG V 1. 137
# IG V 1. 1314
# Poralla 33
#  Pausanias III 16.4 (J. N. Madvig <em>Adversaria criticaad scriptores graecos et latinos</em> 1706)
# IG V 1. 50<span class="smallcaps">b</span>
#  SEG XI 505
#  Steinhauer,BSA 93, pp. 427-447, #1, plate 71a
# Poralla 34
#  Africanus in Eusebius (Schoene) I 196
#  <em>Olymp</em>24
# Poralla 35
#  Strabo XIV 650
#  (<em>Etymologicum Magnum</em> &lt
# T.Gaisford, Oxford 1848&gt
#  s. v. [Akara—he is Cretan)
# Poralla 36
#  Strabo XIV 650
#  (<em>Etymologicum Magnum</em> &lt
# T.Gaisford, Oxford 1848&gt
#  s.v. [Akara—Athymbrados is Cretan)
# IG V 1. 1341
# SEG II 137
# Herodotus IV 149
#  Pausanias III 15.8
# Poralla 37
#  IG V 1. 222
#  Moretti, IAG #9
# Poralla 37
#  IG V 1. 222
#  Moretti, IAG #9
# Poralla 38
#  Pausanias X 10.8
# IG V 1. 679
#  SEG XI 842 <em>addendum
# </em> Rizakis #4
# IG V 1. 91
#  Rizakis #2
# IG V 1. 181
#  SEG XI 636
#  Rizakis #1
# SEG XI 467
# SEG XI 467
# SEG XI 467
# SEG XI 654
# Poralla 39
#  Thucydides II 2
#  Xenophon <em>Hellenica</em> II 3.9
# Poralla 40
#  IG V 1. 703
# Poralla 41
#  Bergk <em>Poetae Lyrici Graeci</em> III p 43 v. 73ff
# IG V 1. 208
# Poralla 42
#  IG V 1. 701
# Poralla 43
#  Pausanias III 18.7
# Poralla 44
#  IG V 1. 702 (̇hΑΙΡΗh—)
# Poralla 45
#  Athenaeus VI 251<span class="smallcaps">f</span> = FGrH86 #13
# IG V 1. 8
# IG V 1. 8
# IG V 1. 209
# IG V 1. 209
# SEG XVII 187
# Poralla 46
#  <em>Olymp</em> 17
#  Africanus in Eusebius (Schoene) I 196.Philostratus <em>Gymnastikos</em> (Jüthner 12)
#  Pausanias V 8.6
# Dionysius Halicarnassus VII 72 (Cf. Eustathius <em>Comm ad Iliadem</em>Y 683, Pausanias I 44.1
# Poralla 47
#  Thucydides V 19, 24
# IG V 1. 803
# Rizakis 35
#  IG V 1. 55<sup>a</sup>, [119?]<sup>b</sup>
# SEG XI 1227, XIV 355, XXIX 408
#  Hanson LGVI no 387 (hexameter plusthree words), C. Gallavotti Metri 34
#  Moretti IAG 8
#  <em>Olymp</em> 160(500 BC?)
# Poralla 48
#  IG V 1. 217
# Poralla 49
#  <em>FDelph</em> III<sub>5</sub> [48I20], [57B15], 58,26,[61B34], [92A23]
# Diodorus Siculus XIX 70.4-71.6<sup>a</sup>, [XX 29.1]
#  Pausanias I13.5, III 6.2, {VIII 27.11-13, VIII 30.7 by name refers to Akrotatos (1)but in fact refers to Akrotatos (2)}
#  Plutarch <em>Agis</em>3.6<sup>b</sup>, <em>Moralia</em> (<em>apophthegmata Laconica</em>)216<span class="smallcaps">de</span>, 240<span class="smallcaps">ef</span> (grandson of Gyrtias)
#  SEG XI 668(?)
#  SEGXXV 444
#  <em>IOlymp</em>, Number 308
#  <em>ICret</em> II xxiii 12A
# {SIG<sup>3</sup> 430, see Akrotatos (2)}
# Athenaeus IV 142<span class="smallcaps">b</span>
#  Parthenius 23
# Plutarch <em>Agis</em> 3.7<sup>a</sup>, <em>Pyrrhus</em>26.18<sup>b</sup>, 28.4-7<sup>c</sup>, <em>Moralia</em>(<em>apophthegmata Laconica</em>) 240<span class="smallcaps">ef</span>}
# Pausanias III 6.6
#  {VIII 27.11-13, VIII 30.7 by name refers to Akrotatos(1) but in fact refers to Akrotatos (2)}
#  SIG<sup>3</sup>430<sup>d</sup> (The editor assigns this inscription to Areus &lt
# 1&gt
# and Akrotatos &lt
# 1&gt
# , but the reference to “King” Akrotatos and“Queen” Chilonis seems to me rather to refer to this Akrotatos.)
# IG IX<sup>2</sup> 29
# Rizakis 249
#  IG V 1. 108
# IG V 1. 127
# IG V 1. 887
# IG V 1. 887
# Rizakis 607
#  IG V 1. 562
# IG V 1. 712 (from AΔEΞAKΩ[N])
# IG V 1. 770 (Ἀλκιλάδα ǀ Ἀλεξάνδρ[α]ς or Ἀλέξανδρ[ο]ς)
# IG V 2. 549
# Athenaeus IV 183c
# Poralla 50
#  Polyaenus VI 10
#  (date: Xenophon <em>Hellenica</em> IV8.18-19)
# Poralla 51
#  Diodorus XV 64.2
# IG V 1. 468 (cf. SEG XI 784)
# IG V 1. 770
# Rizakis 420
#  Steinhauer, BSA 93, pp. 427-447, #4, plate 72b
# SEG XI 854
# IG V 1. 468 (cf. SEG XI 784)
# IG V 1. 726
# IG V 1. 146
# SEG XI 550
# IG V 1. 675
# Rizakis 421
#  IG V 1. 62<sup>a</sup>, 63<sup>b</sup>
#  SEG XI550<sup>c</sup>
# IG V 1. 188
# IG V 1. 51 (Ἀλεσικράτης)<sup>a</sup>, 52<sup>b</sup>, 103 (cf. SEG XI568)<sup>c</sup>
#  SEG XI 538<sup>d</sup>
# IG V 1. 327
# IG V 1. 178
# IG V 1. [51], 52, 103 (cf. SEG XI 568)
#  SEG XI 538
# <em>ICret</em> II xxiii 4B
# IG V 1. 97<sup>a</sup>
#  SEG XI 564<sup>b</sup>, 565 (= IG V 1.20<span class="smallcaps">b</span>)<sup>c</sup>, [569—his name wasomitted from the list of gerontes in the year of Aristokrates and addedabove = ] 642<sup>d</sup>
# IG V 1. 180
# IG V 1. 93
# Poralla 52
#  <em>Anthologia Palatina</em> VII 435
# Poralla 53
#  Xenophon <em>Hellenica</em> II 3.10
#  Thucydides VIII58
# IG V 1. 51<sup>a</sup>, [52]<sup>b</sup>
#  [SEG XI562]<sup>c</sup>
# IG V 1. 161
# IG V 1. 161
# Rizakas 87
#  IG V 1. 817
# Poralla 54
#  <em>Anthologia Palatina</em> VII 435
# Poralla 55
#  Scholia to Aristophanes <em>Equites</em> 84
# <em>Suidas</em> s. v. Παυσανίας (Ἀγειθέα)
#  Polyaenus VIII 51 (Θεανώ)
# Diodorus XI 45,6
#  Nepos <em>Pausanias</em> 5,3
# Poralla 55
#  Scholia to Aristophanes <em>Equites</em> 84
# <em>Suidas</em> s. v. Παυσανίας (Ἀγειθέα)
#  Polyaenus VIII 51 (Θεανώ)
# Diodorus XI 45,6
#  Nepos <em>Pausanias</em> 5,3
# Poralla 56
#  Herodotus VII 204
#  Pausanias III 2.7, IV 4.4
#  FGrH(Apollodorus <em>Chronika)</em> II 244 (86/7)
# Poralla 57
#  Thucydides VIII 5, 8, 10
# Polybius IV 22.11
# IG V 1. 29
# IG V 1. [49], 95, 212
# IG V 1. 78
# Rizakis 6
#  IG V 1. 304<sup>a</sup>, 556<sup>b</sup>, [655 (cf. SEG XI831)]<sup>c</sup>, [682 (cf.
# Rizakis 255 (ca AD 267)
#  IG V 1. 593
# Rizakis 5
#  SEG XI 550
#  A. J. S. Spawforth, ABSA 80, 1985, 247 (cf.SEG 35, 1985, 328) [AD 140s]
# Gerousias [for the second or more time] in the year of Nike[phorosh]o [Markou].
# IG V 1. 78
# IG V 1. 305, 553, 554, 555
#  [SEG XI 802]
# Poralla 58
#  Plutarch <em>Lycurgus</em> 11
#  Pausanias III 18.2
# IG V 1. 97
#  SEG XI 564
# IG V 1. 604
#  SEG XI addenda et corrigenda 812a, 817
# Rizakis 641
#  IG V 1. 32A<sup>a</sup>, [35]<sup>b</sup>,37A<sup>c</sup>, 59 (cf. SEG XI 521<span class="smallcaps">a</span>)<sup>d</sup>, 65<sup>e</sup>,116<sup>f</sup>, [128 (cf. SEG XI 597)]<sup>g</sup>, 289<sup>h</sup>,[290]<sup>i</sup>, 494<sup>j</sup>
#  SEG XI 495<sup>k</sup>,523<sup>l</sup>, 780<sup>m</sup>
# IG V 1. 494, 495
# IG IV<sup>2</sup> 1. 511
# Poralla 59
#  Xenophon <em>Hellenica</em> V 4.56-57
#  Polyaenus II 7
# Poralla 59
#  Xenophon <em>Hellenica</em> V 4.56-57
#  Polyaenus II 7
# IG V 1. 1579
# IG V 1. 141<sup>a</sup>, 465<sup>b</sup>, 578<sup>c</sup>
# Poralla 60
#  Thucydides VIII 6
# SEG XXVII (1977) 135
#  G. Daux, <em>Études Delphique</em>(<em>BCH</em> supplement 4, Paris, 1977) 51-57 (photo)
# Livy XXXIX 35.6-37.21
#  Pausanias VII 9.2-4
#  Polybius XXII 1.9,11.7-12.4
#  XXIII 4.3
# Poralla 61
#  Herodotus VI 61
# Poralla 62
#  Thucydides III 16, 26, 29-33<sup>a</sup>, 69,76-81<sup>b</sup>, 92<sup>c</sup>
#  Diodorus XII 55.6<sup>d</sup>
# Poralla 63
#  Diodorus XV 46.1-3
# Eusebius <em>Chronicorum</em> Libri II (ed. A. Schoene), I, 207,208
# IG V 1. 770 (Ἀλκιλάδα ǀ Ἀλεξάνδρ[α]ς or Ἀλέξανδρ[ο]ς)
# IG V 1. 142
# Poralla 64
#  <em>FDelph</em> III<sub>5</sub> 3 II 54
#  4 III 31
# SEG XI 561
# IG V 1. 141<sup>a</sup>, 299<sup>b</sup>
#  <em>FDelph</em> III 2.160<sup>c</sup>
# SEG XI 561
# Poralla 65
#  Thucydides V 19 (Ἀλκινίδας), 24
# Poralla 66
#  Plutarch <em>Moralia</em> (<em>narrationes amatoriae</em>5) 775<span class="smallcaps">b-e</span>
#  PW
# IG V 1. 210
# IG V 1. 282
# IG V 1. 212
# Rizakis 86 (ca. AD 223)
#  IG V 1. 547<sup>a</sup>, [682]<sup>b</sup>,683<sup>c</sup>
#  SEG XI 798
# IG V 1. 211
# Poralla 67
#  Bergk <em>Poetae Lyrici Graeci</em> III p 46, fr24<sup>a</sup>
#  Herakleides Pontikos II 2 in Müller, <em>FragmentaHistoricorum Graecorum</em>, Paris, 1878, II p 210<sup>b</sup>
# Steinhauer, BSA 93, pp. 427-447, #1, plate 71a
# Poralla 76
#  Pausanias III 16,9
# Poralla 77
#  IG V 1. 1121
# Poralla 78
#  Pausanias III 16.9
# Rizakis 22
#  IG V 1. 128
# IG V 1. 141
# IG V 1. 171 (Upon examination of the squeeze at the Prussian AcademyI found no trace of a P, only scratches more like scars. The P I suspectis due to the too acute desire of the epigrapher to read traces
#  if thisis a name, then it is AN—.)
# IG V 1. 171 (Upon examination of the squeeze at the Prussian AcademyI found no trace of a P, only scratches more like scars. The P I suspectis due to the too acute desire of the epigrapher to read traces
#  if thisis a name, then it is AN—.)
# IG V 1. 125
# Poralla 79
#  Pausanias III 16.6
# Poralla 81
#  Plutarch <em>Moralia</em> (<em>apophthegmataLaconica</em> s. v.
# Poralla 81
#  Plutarch <em>Moralia</em> (<em>apophthegmataLaconica</em> s. v.
# Poralla 82
#  Herodotus VII 204
#  Pausanias III 3.4-5, 14.4, IV 15ff
# Poralla 83
#  <em>Olymp</em> 327
#  Pausanias VI 1.7
# Poralla 84
#  Diodorus XVI 39.6
# Poralla 85
#  IG V 1. 215
# Poralla 86
#  Xenophon <em>Anabasis</em><sup>a</sup> V 1.4, VI 1.16,VII 1.10-20 2.4-8
#
# Poralla 87
#  Pausanias III 7.6, IV 15.3
# Poralla 88
#  Herodotus VIII 131
# Poralla 89
#  Plutarch <em>Solon</em> 10
# IG V 1. 1505
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# IG V 1. 29
# Poralla 91
#  Plutarch <em>Moralia</em> (<em>apophthegmataLaconica</em> s. v.) 217<span class="smallcaps">c</span>
# Eusebius <em>Chronica</em> (ed. A. Schoene) I, 211, 212
# Poralla 92
#  Thucydides V 42
# Poralla 93
#  IG V 1. 1232
# IG V 1. [127], 211
# IG V 1. 124
# IG V 1. 124
# IG V 1. 209
# SEG XI 569
# IG V 1. 63
# IG V 1. 90
# SEG XI 550
# IG V 1. 48
# IG V 1. 133
# Father of Pasiteles (1)
# IG V 1. 306
# SEG XVII 187
# SEG XI 677c (addenda et corrigenda)
# IG V 1. 53<sup>a</sup>, [54]<sup>b</sup>
# Poralla 94
#  Herodotus VII 134
# Poralla 95
#  Thucydides II 67
#  Herodotus VII 134, 137
# Rizakis 25 (I A.D.)
#  IG V 1. 756
# IG V 1. 65
#  SEG XI 523
#  Steinhauer, BSA 93, pp. 427-447, #8, plate75a
# IG V 1. 65
#  SEG XI 523
#  Steinhauer, BSA 93, pp. 427-447, #8, plate75a
# Poralla 96
#  Stephanus Byzantius s. v. Ἀνθάνα
#  Alan Griffiths, ‟WasCleomenes Mad,” <em>Classical Sparta: Techniques Behind HerSuccess</em>, Norman, 1988, pp. 62-67
# SEG XI 863
# SEG XI 540
# Rizakis 552
#  IG V 1. 129
# IG V 1. 248
# Son of Pank— or pank(ratiastes?)
# SEG XI 497
# IG V 1. 812
#  Antoninus Liberalis 12 = Pausanias III 13.8 Areios
# Diodorus Siculus XX 29.1<sup>a</sup>
#  Justin XXIV 1.5
#  PompeiusTrogus <em>prologi</em> 26
#  Pausanias I 13.5
#  III 6.2-6<sup>b</sup>
#  VI12.5-6, 15.9
#  Plutarch <em>Agis</em> 3.6-7<sup>c</sup>, <em>Pyrrhus</em>26.17-19<sup>d</sup>, 27.2<sup>e</sup>, 29.11<sup>f</sup>, 30.4,<em>Moralia</em> (<em>apophthegmata Laconica</em>) 217<span class="smallcaps">f</span><sup>g</sup>
#  Josephus <em>AntiquitatesJudaicae</em> XII 225-27<sup>h</sup>, XIII 167 (ΑΡΕΙΟΣ)
#  1<em>Maccabees</em> 12.1-23
#  Athenaeus IV 142<span class="smallcaps">b</span>
#  <em>ICret</em> II xxiii 12A<sup>i</sup>
# <em>IOlymp</em> 308<sup>j</sup>
#  IG IV 1. 332
#  SEG XXV 444<sup>k</sup>
# SEG XI 668 (?—Dedication to Athena)
#  [SIG<sup>3</sup> 430, see Areus (2)II]
#  Grunauer, pp. 112-113 (Gr. I-II, Tafel 1: ΒΑΣΥΛΕΟΣ ΑΡΕΟΣ)
# SIG<sup>3</sup> 430
#  Pausanias III 6.6
#  Plutarch <em>Agis</em> 3.7-8
# [<em>Pyrrhus</em> 26.17-18]
# Livy XXXIX 35-37
#  Pausanias VII 9.2-4
#  Polybius XXII 1.9 &amp
# 11.7-12.4
#  XXIII 4.3
# Rizakis 699
#  IG V 1. 20<span class="smallcaps">b</span><sup>a</sup>
# SEG XI 511<sup>b</sup>, 608<sup>c</sup>
# Polybius XI 18.3-5
# Poralla 114
#  IG V 1. 255
#  <em>Orthia</em> 1 (p. 296), Moretti<em>IAG</em> 18
# IG V 1. 210
# IG V 1. 210
# IG V 1. 210
# IG V 1. 210
# IG V 1. 317
# IG V 1. 94
# Poralla 115
#  Plutarch <em>Lycurgus</em> 5
# Grunauer, Gruppe VIII, Serie 5 (<img alt="Esigla 05" src="media/image7.jpeg" style="width:0.34722in
# height:0.10417in"/>), Tafel 4(19, 21)
# Grunauer, p. 53 (emission mark 8 <img alt="sigla 08" src="media/image8.jpeg" style="width:0.17361in
# height:0.10417in"/>), Gruppe XIV(48-40 BC), Serie 12, Tafel 8, Gruppe XV (48-40 BC), Serie 12-13, Tafel9, Gruppe XVI (43-31 BC), Serie 3, Tafel 11, Gruppe XVII (43-31 BC),Serie 2, Tafel 13 suggests Aristokratidas, Aristomachos, orAristokles
# <em>Archaiologikon Deltion</em> 24 (1969) <em>Chronica</em> p. 136,pl. 132 (<em>BCH</em>
# Poralla 116
#  <em>FDelph</em> III<sub>5</sub> 92 A 30
# IG V 1. 254
# Gravemarker: twenty-three years old at death
# Gravemarker: twenty-three years old at death
# Gravemarker: twenty-three years old at death
# SEG XI 532
# SEG XI 532
# IG V 1. 965
# SEG XI 515
# <em>The Flinders Petrie Papyri</em>, Part 2, ed. J. P. Mahaffy (RoyalIrish Academy, Cunningham Memoirs, Number 9), Dublin, 1891-1905, II 35(a), column I, line 6
# IG V 1. 212
# IG V 1. 261
# IG V 1. 126
# Rizakis 96
#  IG V 1. 529<sup>a</sup>, 530<sup>b</sup>,653A<sup>c</sup>
# IG IV<sup>2</sup> 1. 85, 86, 681
# Rizakis 727
#  IG V 1. 32B<sup>a</sup>, 158 (cf. SEG XI631)<sup>b</sup>
#  SEG XI [542]<sup>c</sup>, 569<sup>d</sup>
# Rizakis 726/730 (Stemmata I, VII, XIII)
#  IG V 1. [68]<sup>a</sup>,[295]<sup>b</sup>, 477<sup>c</sup>
#
# SEG XI 558
# IG V 1. 48
# Rizakis 734
#  IG V 1. 46 {M = e.g. [Πo]μ(πήιος)}
#  SEG XI 516
# Rizakis 97
#  IG V 1. 556
# SEG XI 512<sup>a</sup>, 562<sup>b</sup>
# Plutarch <em>Lycurgus</em> 4.8, 31.10, <em>Philopoemen</em> 16.4
# Athenaeus III 82E
#  Scholia to Aristophanes <em>Nubes</em> 971
#  Scholiato Sophocles <em>Trachiniae</em> 266
#  Stephanus Byzantius<em>Ethnika</em> s. v. Abantis
#  <em>FGrH</em> 591
# Rizakis 705
#  IG V 1. 287<sup>a</sup>
#  SEG XI 518<sup>b</sup>
# IG V 1. 103<sup>a</sup>, 483<sup>b</sup>
#  SEG XI 537<sup>c</sup>,569<sup>d</sup>
# Steinhauer, BSA 93, pp. 427-447, #1, plate 71a
# SEG XI 608
# IG V 1. 96<sup>a</sup>, 209<sup>b</sup>, 211<sup>c</sup>
# SEG XI 839
# Grunauer, p. 53 (emission mark 22 <img alt="sigla 22b" src="media/image10.jpeg" style="width:0.20139in
# height:0.125in"/>), Gruppe XVI(43-31 BC), Serie 17, Tafel 12, Gruppe XVII (43-31 BC), Serie 12, Tafel13, Gruppe XXI (35-31 BC), Serie 1, Tafel 17 associated on a coin withDamares (6a)
#  Grunauer, p. 53 (emission mark 23 <img alt="sigla 23" src="media/image11.jpeg" style="width:0.20139in
# height:0.11806in"/>), Gruppe XVII (43-31 BC), Serie 13, Tafel 13,Aristokrates only: Gruppe XXI (35-31 BC), Serie 2, Tafel 17 associatedon a coin with Timaristos
# IG V 1. 82 (cf. SEG XI 545)
#  SEG XI 559, 605
# Rizakis 262
#  IG V 1. 71
# Rizakis 261 (Stemmata I &amp
#  IX)
#  IG V 1. 469<sup>a</sup>,607<sup>b</sup>
# IG V 1. 159
# IG V 1. 59
#  SEG XI 521<span class="smallcaps">b</span>
# Steinhauer, BSA 93, pp. 427-447, #4, plate 72b
# IG V 1. 20<span class="smallcaps">b</span>
# IG V 1. 66 (cf. SEG XI 524)
# IG IV<sup>2</sup> 1. 96 xvi
# IG V 1. 124
# IG V 1. 680
# IG V 1. 49, 210
#  [SEG XI 676]
# IG V 1. 103
#  SEG XI 537
# IG V 1. 26
# IG V 1. 195
# IG V 1. 61 (cf. SEG XI 519 from —ΙΛΥΟΚ...ΟΥΣ)
# IG V 1. 141, 211
# IG V 1. 209
# SEG XI 511
# Poralla 129
#  Plutarch <em>Lysander</em> 2
#  IG II<sup>2</sup> 1388line 32, 1400 line 15
#  Pausanias VI 3.14
#  Xenophon <em>Hellenica</em> II4.28
#  Diodorus XIV 13.5/6
# Poralla 129
#  Plutarch <em>Lysander</em> 2
#  IG II<sup>2</sup> 1388line 32, 1400 line 15
#  Pausanias VI 3.14
#  Xenophon <em>Hellenica</em> II4.28
#  Diodorus XIV 13.5/6
# IG V 1. 212
# IG V 1. 212
# IG V 1. 210<sup>a</sup>, 212<sup>b</sup>
# IG V 1. 210<sup>a</sup>, 212<sup>b</sup>
# SEG XI 676
# SEG XI 414
# IG V 1. 211
# Poralla 130
#  Xenophon <em>Hellenica</em> V 4.22
# Poralla 131
#  IG V 1. 1345a (letter forms = fifth century)
# Poralla 132
#  IG V 1. 1134
# IG IX<sup>2</sup> 28
# IG V 1. 211
# IG V 1. 212
# IG V 1. 258
# Poralla 133
#  Polyaenus II 31.1
# IG V 1. 209
# IG V 1. 103
# IG V 1. 66 (cf. SEG XI 524)<sup>a</sup>, [128 (cf. SEG XI597]<sup>b</sup>
# IG V 1. 97<sup>a</sup>, [128 (cf. SEG XI 597]<sup>b</sup>, 674 (cf.SEG XI 842)<sup>c</sup>
#  SEG XI 564<sup>d</sup>
# SEG XI 468
# IG V 1. 209
# IG V 1. 209
# IG V 1. 103
# Poralla 134
#  Pausanias III 9.3
# IG V 1. 102 (Ἀριστομενούδας, cf. SEG XI 579)<sup>a</sup>
#  SEG XI544<sup>b</sup>
# SEG XI 518
# IG V 1. 134
# SEG XI 681
# Daughter of Nikokrates (14)
# IG V 1. 60
# IG V 1. 97<sup>a</sup>
#  SEG XI 561<sup>b</sup>, 564<sup>c</sup>,605<sup>d</sup>
# IG V 1. 20<span class="smallcaps">b</span><sup>a</sup>, 36<span class="smallcaps">b</span><sup>b</sup>
#  SEG XI 517<sup>c</sup>,540<sup>d</sup>, 611<sup>e</sup>
#  BSA XXVI 168, C6, C7<sup>f</sup>
# IG V 1. 59 (cf. SEG XI 548)<sup>a</sup>, 116<sup>b</sup>
# IG V 1. 32A
#  SEG XI 617 ([Ἀριστ— or Δαμ—ον]εικίδ[ας])
# IG V 1. 92
# IG IX 2. 518
# Rizakis 210
#  IG V 1. 154
# IG V 1. 211
# IG V 1. 142
# IG V 1. 126
# IG V 1. 53
# IG V 1. 142
# IG V 1. 886 (= Ἀρίστονο[ς], genitive of Ἀρίστων?)
# IG V 1. 152
# IG V 1. 209 (or is <em>aristopolis</em> a title?)
# Poralla 135
#  Diodorus XIV 10, 70.3 (Ἀρέτης)
# Poralla 136
#  IG V 1. 1230
# Poralla 137
#  Diodorus XIV 78.1
# Rizakis 99 (appendix, stemma iii)
#  IG V 1. 601<sup>a</sup>,1240<sup>b</sup>
# Rizakis 266
#  IG V 1. 836
# Rizakis 619 (Stemma 10)
#  IG V 1. 303
# Rizakis 263 (“three individuals”), 264 (Stemmata I &amp
#  VII), 265,267
#  IG V
# IG V 1. 264
# Rizakis 214
#  IG V 1. 39, 69, 70, 71
#  SEG XI 526, 554
# IG V 1. 27
# IG V 1. 695
# IG V 1. 284
# IG V 1. 286
# Iamblichus <em>de vita Pythagorica</em> 267, cf. Δαμάγητος
#  Plutarch<em>Moralia</em> (de aud. poet 14)
#  86c, 96a, 148a, 151-156, 163d, 284c,385e
#  Plato <em>Protagoras</em> 343<span class="smallcaps">a</span>.
# Eusebius (Schoene) II 96/7
#  FGrH II (Apollodorus <em>Chronika</em>) p183ff
#  Pausanias III 16.4, X 24.4
#  Libanius <em>declamations</em> 2.9
# Anthologia Graeca VII 81, IX 366
#  SEG XXIX 1123 (represented withSocrates in Ephesus, AD 200-220)
#  Aulus Gellius I 3.1-8
#  DiogenesLaertius I 30, 41
#  Aristotle rhetorica 1389b4, 14
#
# Poralla 760
#  Diogenes Laertius I 68, 69
#  <em>Suidas</em> s. v.
# Iamblichus <em>de vita Pythagorica</em> 267, cf. Δαμάγητος
#  Plutarch<em>Moralia</em> (de aud. poet 14)
#  86c, 96a, 148a, 151-156, 163d, 284c,385e
#  Plato <em>Protagoras</em> 343<span class="smallcaps">a</span>.
# Eusebius (Schoene) II 96/7
#  FGrH II (Apollodorus <em>Chronika</em>) p183ff
#  Pausanias III 16.4, X 24.4
#  Libanius <em>declamations</em> 2.9
# Anthologia Graeca VII 81, IX 366
#  SEG XXIX 1123 (represented withSocrates in Ephesus, AD 200-220)
#  Aulus Gellius I 3.1-8
#  DiogenesLaertius I 30, 41
#  Aristotle rhetorica 1389b4, 14
#
# Poralla 760
#  Diogenes Laertius I 68, 69
#  <em>Suidas</em> s. v.
# Iamblichus <em>de vita Pythagorica</em> 267, cf. Δαμάγητος
#  Plutarch<em>Moralia</em> (de aud. poet 14)
#  86c, 96a, 148a, 151-156, 163d, 284c,385e
#  Plato <em>Protagoras</em> 343<span class="smallcaps">a</span>.
# Eusebius (Schoene) II 96/7
#  FGrH II (Apollodorus <em>Chronika</em>) p183ff
#  Pausanias III 16.4, X 24.4
#  Libanius <em>declamations</em> 2.9
# Anthologia Graeca VII 81, IX 366
#  SEG XXIX 1123 (represented withSocrates in Ephesus, AD 200-220)
#  Aulus Gellius I 3.1-8
#  DiogenesLaertius I 30, 41
#  Aristotle rhetorica 1389b4, 14
#
# A distinguished Spartan, son of Demarmenos, brother of Prinetadas andfather of Perkalos, the wife of king Damaratos
# Brother-in-law of Archidamos III, fell in 364 before Kromnos. Heprobably belonged to the family of the wise Chilon.
# He led a party of the followers of Kleomenes (1) III in killing theephors, 219 BC
# Poralla 763
#  Polyaenus VIII 34
#  Quintilian <em>institutes</em> II17.20
#  Plutarch <em>Lycurgus</em> 7
# Poralla 763
#  Polyaenus VIII 34
#  Quintilian <em>institutes</em> II17.20
#  Plutarch <em>Lycurgus</em> 7
# Plutarch [<em>Agis</em> 3.7], <em>Pyrrhus</em> 26.17<sup>a</sup>,18-24<sup>b</sup>, 27.10, 28.5-6
#  Parthenius 23<sup>c</sup>
# SIG<sup>3</sup> 430<sup>d</sup>
#  RE VII 2280: Chilonis (3)
# Plutarch [<em>Agis</em> 3.7], <em>Pyrrhus</em> 26.17<sup>a</sup>,18-24<sup>b</sup>, 27.10, 28.5-6
#  Parthenius 23<sup>c</sup>
# SIG<sup>3</sup> 430<sup>d</sup>
#  RE VII 2280: Chilonis (3)
# She accompanied her father into exile, 242 BC, and after his returninterceded for Kleombrotos, who had assumed the throne in her father'sabsence.
# Poralla 765
#  Joannes of Antioch fr. 27 in Müller, <em>FragmentaHistoricorum Graecorum</em>, Paris, 1878, IV 540 (Χίονος)
#  Pausanias III14.3, IV 23.4, 10, VIII 39.3
#  Africanus in Eusebius I 198
# <em>Olymp</em> 42-47
# Poralla 765
#  Joannes of Antioch fr. 27 in Müller, <em>FragmentaHistoricorum Graecorum</em>, Paris, 1878, IV 540 (Χίονος)
#  Pausanias III14.3, IV 23.4, 10, VIII 39.3
#  Africanus in Eusebius I 198
# <em>Olymp</em> 42-47
# The chronology of his office is loaded with difficulties since Polliswas nauarch in 396/95 and Peisandros for 395/4 and so there is no roomfor Cheirikrates (but the Oxyrhynchus historian writes that he arrivedas nauarch and the successor of Pollis). A couple of solutions have beenproposed: that Ch. filled out an abbreviated term of Pollis or thatPeisandros was appointed to a command by Agesilaus but was not actuallynauarch.
# The chronology of his office is loaded with difficulties since Polliswas nauarch in 396/95 and Peisandros for 395/4 and so there is no roomfor Cheirikrates (but the Oxyrhynchus historian writes that he arrivedas nauarch and the successor of Pollis). A couple of solutions have beenproposed: that Ch. filled out an abbreviated term of Pollis or thatPeisandros was appointed to a command by Agesilaus but was not actuallynauarch.
# Poralla 759
#  Xenophon <em>Anabasis</em> I 4.3 , III 4.38, IV 1.6,3.27, 6.14, V 1.3-5, VI 1.16, 2.12-18, 4.11, 31-32
#  Diodorus XIV 19.5,27.1, 30.4-5
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# IG V 1. 20<span class="smallcaps">b</span>, [184 (Ὀνησ— —τος)
#  A. M.Woodward, ABSA XXVI (1925) 168, C6, C7
# Son-in-law of M. Aurelius Chrysogonos (4)<sup>b</sup>, hence thehusband of (Aurelia) Sophrosyna
# Son-in-law of M. Aurelius Chrysogonos (4)<sup>b</sup>, hence thehusband of (Aurelia) Sophrosyna
# Son-in-law of M. Aurelius Chrysogonos (4)<sup>b</sup>, hence thehusband of (Aurelia) Sophrosyna
# Gymnasiarch and subject of a decree of the city for brilliantlyexecuting the duties of that office<sup>bc</sup>
# Gymnasiarch and subject of a decree of the city for brilliantlyexecuting the duties of that office<sup>bc</sup>
# A Spartiate, who in 378 and in Winter 370/69 was an ambassador in
# A Spartiate, who in 378 and in Winter 370/69 was an ambassador in
# A Spartiate, who in 378 and in Winter 370/69 was an ambassador in
# Leader of the embassy to Philip V after the murder of members of thepro-Macedonian party, 220 BC
# Data extraction complete. Saved to 'output_with_ids8.json'.

# %%
from rdflib import Graph, URIRef, Literal, Namespace
from rdflib.namespace import DC, FOAF, RDF, RDFS
from urllib.parse import quote
import hashlib
import json

# Function to generate a unique ID based on the name and date
def generate_id(entry):
    unique_string = f"{entry['Name']}_{entry['Date']}"
    return hashlib.md5(unique_string.encode()).hexdigest()

# Load the structured data
with open("output_with_ids.json", "r", encoding="utf-8") as f:
    data = json.load(f)

    # Create an RDF graph
    g = Graph()

    # Define namespaces
    EX = Namespace("http://example.org/ontology/")  # Custom namespace for your data
    CRM = Namespace("http://www.cidoc-crm.org/cidoc-crm/")

    g.bind("ex", EX)
    g.bind("dc", DC)
    g.bind("foaf", FOAF)
    g.bind("crm", CRM)

    # Add entries to the graph
    for entry in data:
        # Generate a unique ID for the person
        unique_id = generate_id(entry)
        person_uri = URIRef(f"http://example.org/person/{unique_id}")

        # Encode the person URI
        person_uri = URIRef(f"http://example.org/person/{quote(entry['Name'])}")
        g.add((person_uri, RDF.type, CRM.E21_Person))
        g.add((person_uri, FOAF.name, Literal(entry["Name"])))
        g.add((person_uri, DC.date, Literal(entry["Date"])))
        # Add a human-readable label
        g.add((person_uri, RDFS.label, Literal(entry["Name"])))
        # Add the unique ID as a property
        g.add((person_uri, EX.hasID, Literal(unique_id)))

        # Add sources
        for source in entry["Sources"]:
            # Encode source URI
            source_uri = URIRef(f"http://example.org/source/{quote(source['Resource'])}")
            g.add((person_uri, EX.hasSource, source_uri))
            g.add((source_uri, EX.hasReference, Literal(source["Reference"])))

        # Add facts
        for fact in entry["Facts"]:
            fact_node = URIRef(f"http://example.org/fact/{quote(fact['Fact'])}")
            g.add((person_uri, EX.hasFact, fact_node))
            g.add((fact_node, DC.description, Literal(fact["Fact"])))
            for ref in fact["Sources"]:
                g.add((fact_node, EX.hasSourceReference, Literal(ref)))

# Save the RDF graph to a file
output_rdf_file = "output.ttl"
g.serialize(destination=output_rdf_file, format="turtle")

print(f"RDF data saved to '{output_rdf_file}'.")
# Out:
# RDF data saved to 'output.ttl'.
